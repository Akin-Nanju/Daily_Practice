# %%
import pandas as pd
dfl = pd.read_csv(r"C:\Users\NITRO V\Downloads\students.csv")
dfr = pd.read_csv(r"C:\Users\NITRO V\Downloads\grades.csv")
dfl
# Out:
#    Student_ID     Name  Age
# 0           1    Alice   20
# 1           2      Bob   21
# 2           3  Charlie   19
# 3           4    Diana   22

# %%
dfr
# Out:
#    Student_ID     Course Grade
# 0           1       Math     A
# 1           2    Physics    B+
# 2           3  Chemistry    A-
# 3           5    Biology     B

# %%
dfl.merge(dfr)
# Out:
#    Student_ID     Name  Age     Course Grade
# 0           1    Alice   20       Math     A
# 1           2      Bob   21    Physics    B+
# 2           3  Charlie   19  Chemistry    A-

# %%
dfl.merge(dfr, how = 'outer', on = 'Student_ID')
# Out:
#    Student_ID     Name   Age     Course Grade
# 0           1    Alice  20.0       Math     A
# 1           2      Bob  21.0    Physics    B+
# 2           3  Charlie  19.0  Chemistry    A-
# 3           4    Diana  22.0        NaN   NaN
# 4           5      NaN   NaN    Biology     B

# %%
dfl.merge(dfr, how = 'inner', on = 'Student_ID')
# Out:
#    Student_ID     Name  Age     Course Grade
# 0           1    Alice   20       Math     A
# 1           2      Bob   21    Physics    B+
# 2           3  Charlie   19  Chemistry    A-

# %%
dfl.merge(dfr, how = 'left')
# Out:
#    Student_ID     Name  Age     Course Grade
# 0           1    Alice   20       Math     A
# 1           2      Bob   21    Physics    B+
# 2           3  Charlie   19  Chemistry    A-
# 3           4    Diana   22        NaN   NaN

# %%
dfl.merge(dfr, how = 'right')
# Out:
#    Student_ID     Name   Age     Course Grade
# 0           1    Alice  20.0       Math     A
# 1           2      Bob  21.0    Physics    B+
# 2           3  Charlie  19.0  Chemistry    A-
# 3           5      NaN   NaN    Biology     B

# %%
dfl.merge(dfr, how = 'cross')
# Out:
#     Student_ID_x     Name  Age  Student_ID_y     Course Grade
# 0              1    Alice   20             1       Math     A
# 1              1    Alice   20             2    Physics    B+
# 2              1    Alice   20             3  Chemistry    A-
# 3              1    Alice   20             5    Biology     B
# 4              2      Bob   21             1       Math     A
# 5              2      Bob   21             2    Physics    B+
# 6              2      Bob   21             3  Chemistry    A-
# 7              2      Bob   21             5    Biology     B
# 8              3  Charlie   19             1       Math     A
# 9              3  Charlie   19             2    Physics    B+
# 10             3  Charlie   19             3  Chemistry    A-
# 11             3  Charlie   19             5    Biology     B
# 12             4    Diana   22             1       Math     A
# 13             4    Diana   22             2    Physics    B+
# ...

# %%
a = pd.concat([dfl.fillna("UNAVILABLE"),dfr.fillna("UNAVILABLE")])
# Out:
#    Student_ID     Name   Age     Course Grade
# 0           1    Alice  20.0        NaN   NaN
# 1           2      Bob  21.0        NaN   NaN
# 2           3  Charlie  19.0        NaN   NaN
# 3           4    Diana  22.0        NaN   NaN
# 0           1      NaN   NaN       Math     A
# 1           2      NaN   NaN    Physics    B+
# 2           3      NaN   NaN  Chemistry    A-
# 3           5      NaN   NaN    Biology     B

# %%
dfl['Course'] = None
dfl
# Out:
#    Student_ID     Name  Age Course
# 0           1    Alice   20   None
# 1           2      Bob   21   None
# 2           3  Charlie   19   None
# 3           4    Diana   22   None

# %%
pd.concat([dfl.fillna("UNAVILABLE"),dfr.fillna("UNAVILABLE")])
# Out:
#    Student_ID     Name   Age      Course Grade
# 0           1    Alice  20.0  UNAVILABLE   NaN
# 1           2      Bob  21.0  UNAVILABLE   NaN
# 2           3  Charlie  19.0  UNAVILABLE   NaN
# 3           4    Diana  22.0  UNAVILABLE   NaN
# 0           1      NaN   NaN        Math     A
# 1           2      NaN   NaN     Physics    B+
# 2           3      NaN   NaN   Chemistry    A-
# 3           5      NaN   NaN     Biology     B
