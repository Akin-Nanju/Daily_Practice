# %% [markdown]
# PANDAS VISUALIZATION

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\NITRO V\Downloads\visualization_practice.csv")
df
# Out:
#    Country  Population  GDP_Per_Capita  Internet_Users  Life_Expectancy
# 0      USA         331           65112             292               79
# 1    China        1441           10500             989               77
# 2    India        1393            2170             743               70
# 3  Germany          83           46889              80               81
# 4   Brazil         213            8697             159               75

# %%
df.plot(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.plot(kind = 'bar', title = 'PRACTICE VISUALIZATION')
# Out:
# <Axes: title={'center': 'PRACTICE VISUALIZATION'}>

# %%
df['Population'].plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'scatter', x = 'Country', y = 'Population')
# Out:
# <Axes: xlabel='Country', ylabel='Population'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: >

# %%
df.plot.pie(y = 'Population')
# Out:
# <Axes: ylabel='Population'>
